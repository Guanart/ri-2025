# %% [markdown]
# # Ejercicio 1 - Indexado BSBI y corpus de Wikipedia

# %%
import os
import time
import matplotlib.pyplot as plt
import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))
from lib.IndexadorBSBI import IndexadorBSBI
from lib.Tokenizador import Tokenizador

CORPUS_PATH: str = "../datos/"
INDEX_DIR: str = "../index"


# Analiza la colección: cuenta documentos y suma tamaño total (solo .txt y .html)
def analizar_corpus(corpus_path: str) -> tuple[int, int]:
    total_docs: int = 0
    total_size: int = 0
    for root, _, files in os.walk(corpus_path):
        for fname in files:
            if fname.endswith((".txt", ".html")):
                total_docs += 1
                total_size += os.path.getsize(os.path.join(root, fname))
    return total_docs, total_size


total_docs: int
size_corpus: int
total_docs, size_corpus = analizar_corpus(CORPUS_PATH)
print(f"Total de documentos en la colección: {total_docs}")
print(f"Tamaño total de la colección: {size_corpus/1024/1024:.2f} MB")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       2 import time
#       3 import matplotlib.pyplot as plt
# ----> 5 from lib.IndexadorBSBI import IndexadorBSBI
#       6 from lib.Tokenizador import Tokenizador
#       8 CORPUS_PATH: str = "../datos/"
#
# ModuleNotFoundError: No module named 'lib'

# %% [markdown]
# ## Prueba con varios valores de n (10%, 20%, 50% del total)

# %%
from typing import List, Dict, Any

n_values = [max(1, int(total_docs * frac)) for frac in [0.1, 0.2, 0.5]]
resultados: List[Dict[str, Any]] = []

for n in n_values:
    print(f"\nIndexando con n = {n} (volcado cada {n} documentos)...")
    tokenizer = Tokenizador()
    indexador = IndexadorBSBI(tokenizer, memory_limit=n, path_index=f"{INDEX_DIR}_n{n}")

    # Indexación
    t0 = time.time()
    indexador.index_collection(CORPUS_PATH)
    t1 = time.time()
    sizes = indexador.index_size_on_disk()
    posting_sizes = indexador.posting_list_sizes()

    resultados.append(
        {
            "n": n,
            "tiempo_total": t1 - t0,
            "size_postings": sizes["size_postings"],
            "size_vocab": sizes["size_vocab"],
            "posting_sizes": posting_sizes,
        }
    )
# Out:
# Indexando con n = 604 (volcado cada 604 documentos)...
# Iniciando indexado (BSBI)...
# Procesando documento 2: Hoher_Dachstein_5df8.html
# Procesando documento 1556: Woodstock~_Music_from_the_Original_Soundtrack_and_More_8af2.htmllbutterfly_cea0.html_8896.html
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 13
#      11 # Indexación
#      12 t0 = time.time()
# ---> 13 indexador.index_collection(CORPUS_PATH)
#      14 t1 = time.time()
#      15 sizes = indexador.index_size_on_disk()
#
# File ~/RI/ri-2025/TP04 - Estructuras de Datos/lib/IndexadorBSBI.py:79, in IndexadorBSBI.index_collection(self, docs_path)
#      75 doc_id += 1
#      76 print(
#      77     f"\rProcesando documento {doc_id}: {fname}", end="", flush=True
#      78 )
# ---> 79 tokens, doc_name = self._process_doc(fname, root, docs_path)
#      80 terms_freq = Counter(tokens)
#      81 for token, freq in terms_freq.items():
#
# File ~/RI/ri-2025/TP04 - Estructuras de Datos/lib/IndexadorBSBI.py:117, in IndexadorBSBI._process_doc(self, fname, root, path)
#     115     text = f.read()
#     116     if fname.endswith(".html"):
# --> 117         text: str = BeautifulSoup(text, "html.parser").get_text(separator=" ")
#     118         """
#     119         ACÁ SE PODRÍA HACER UN PARSEO MÁS COMPLEJO DEL HTML (usando BeautifulSoup)
#     120         """
#     121 tokens = self.tokenizer.tokenizar(text)
#
# File ~/RI/ri-2025/custom_env/lib/python3.12/site-packages/bs4/__init__.py:473, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     471 self.builder.initialize_soup(self)
#     472 try:
# --> 473     self._feed()
#     474     success = True
#     475     break
#
# File ~/RI/ri-2025/custom_env/lib/python3.12/site-packages/bs4/__init__.py:658, in BeautifulSoup._feed(self)
#     655 self.builder.reset()
#     657 if self.markup is not None:
# --> 658     self.builder.feed(self.markup)
#     659 # Close out any unfinished strings and close all the open tags.
#     660 self.endData()
#
# File ~/RI/ri-2025/custom_env/lib/python3.12/site-packages/bs4/builder/_htmlparser.py:467, in HTMLParserTreeBuilder.feed(self, markup)
#     464 parser = BeautifulSoupHTMLParser(self.soup, *args, **kwargs)
#     466 try:
# --> 467     parser.feed(markup)
#     468     parser.close()
#     469 except AssertionError as e:
#     470     # html.parser raises AssertionError in rare cases to
#     471     # indicate a fatal problem with the markup, especially
#     472     # when there's an error in the doctype declaration.
#
# File /usr/lib/python3.12/html/parser.py:111, in HTMLParser.feed(self, data)
#     105 r"""Feed data to the parser.
#     106
#     107 Call this as often as you want, with as little or as much text
#     108 as you want (may include '\n').
#     109 """
#     110 self.rawdata = self.rawdata + data
# --> 111 self.goahead(0)
#
# File /usr/lib/python3.12/html/parser.py:171, in HTMLParser.goahead(self, end)
#     169 if startswith('<', i):
#     170     if starttagopen.match(rawdata, i): # < + letter
# --> 171         k = self.parse_starttag(i)
#     172     elif startswith("</", i):
#     173         k = self.parse_endtag(i)
#
# File /usr/lib/python3.12/html/parser.py:313, in HTMLParser.parse_starttag(self, i)
#     311 match = tagfind_tolerant.match(rawdata, i+1)
#     312 assert match, 'unexpected call to parse_starttag()'
# --> 313 k = match.end()
#     314 self.lasttag = tag = match.group(1).lower()
#     315 while k < endpos:
#
# KeyboardInterrupt:

# %%
print("Resultados:")
for i, r in enumerate(resultados):
    print(f"n={r['n']}:")
    print(f"  Tiempo total: {r['tiempo_total']:.2f} segundos")
    print(f"  Tamaño del índice en disco: {r['size_postings'] + r['size_vocab']} bytes")
    print(f"  Tamaño de postings: {r['size_postings']} bytes")
    print(f"  Tamaño de vocabulario: {r['size_vocab']} bytes")
    print(f"  Cantidad de posting lists: {len(r['posting_sizes'])}")
    print(f"  Tamaño máximo de posting list: {max(r['posting_sizes'])}")
# Out:
# Resultados:
# n=604:
#   Tiempo total: 78.55 segundos
#   Tamaño del índice en disco: 20797096 bytes
#   Tamaño de postings: 15735720 bytes
#   Tamaño de vocabulario: 5061376 bytes
#   Cantidad de posting lists: 198216
#   Tamaño máximo de posting list: 6043
# n=1208:
#   Tiempo total: 76.60 segundos
#   Tamaño del índice en disco: 20797096 bytes
#   Tamaño de postings: 15735720 bytes
#   Tamaño de vocabulario: 5061376 bytes
#   Cantidad de posting lists: 198216
#   Tamaño máximo de posting list: 6043
# n=3021:
#   Tiempo total: 71.06 segundos
#   Tamaño del índice en disco: 20797096 bytes
#   Tamaño de postings: 15735720 bytes
#   Tamaño de vocabulario: 5061376 bytes
#   Cantidad de posting lists: 198216
#   Tamaño máximo de posting list: 6043

# %% [markdown]
# ## Gráfica: Tiempos de indexación para cada valor de N

# %%
plt.figure(figsize=(8, 5))
plt.plot(
    [r["n"] for r in resultados], [r["tiempo_total"] for r in resultados], marker="o"
)
plt.xlabel("n (tamaño de bloque para volcado parcial)")
plt.ylabel("Tiempo total de indexación (s)")
plt.title("Tiempos de indexación para cada valor de N")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Gráfica: Distribución de tamaños de posting lists
# La distribución es la misma para los tres tamaños de N (solo se muestra un caso).

# %%
plt.figure(figsize=(8, 5))
plt.hist(resultados[0]["posting_sizes"], bins=100, edgecolor="black", log=True)
plt.xlabel("Tamaño de posting list (df)")
plt.ylabel("Cantidad de términos")
plt.title(f"Distribución de tamaños de posting lists")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Cálculo del overhead del índice respecto de la colección

# %%
for r in resultados:
    overhead = (r["size_postings"] + r["size_vocab"]) / size_corpus
    print(f"n={r['n']}: Overhead del índice = {overhead*100:.2f}%")
# Out:
# n=604: Overhead del índice = 13.58%
# n=1208: Overhead del índice = 13.58%
# n=3021: Overhead del índice = 13.58%
